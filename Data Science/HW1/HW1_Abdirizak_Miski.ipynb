# %% [markdown]
# ## Homework 1 - Data Exploration using Census Data
#
# In this homework assignment you will use census data from the 1994 and 1995 current population surveys conducted by the U.S. Census Bureau. A copy of this dataset is located at UCI Machine Learning repository, please see this [link](https://archive.ics.uci.edu/ml/datasets/Census-Income+%28KDD%29) to reach to the dataset website.
#
# This dataset contains census data extracted from the 1994 and 1995 Current Population Surveys. We will only work with 'training' data (a link to that is provided to you below). The data contains 41 demographic and employment related variables. The abbreviated column names provided to you below. You are expected to read the documentation of this dataset, understand the features and preprocess this dataset. Additional information can be found [in the data description](https://archive.ics.uci.edu/ml/machine-learning-databases/census-income-mld/census-income.data.html) and [additional comments](https://archive.ics.uci.edu/ml/machine-learning-databases/census-income-mld/census-income.names).
#
# Below you will find a code snippet to read the data into a pandas dataframe. You can alternatively download it yourself, extract and read it manually. The questions are shown in the subsequent cells. You need to provide your answers in this file.
#
# Your code is expected to have no errors, please make sure all your cells run properly before submitting (click Kernel->Restart & Run All to see if your code sequence works).
#
# __Please change the notebook's name and add your name before submitting.__

# %%
import pandas as pd
import numpy as np

# %%
import urllib.request
url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/census-income-mld/census-income.data.gz'
census_dl_file = './census-income.data.gz'
urllib.request.urlretrieve(url, census_dl_file)
# Out:
# ('./census-income.data.gz', <http.client.HTTPMessage at 0x7fe8523902e0>)

# %%
columns_abbr = ['AAGE', 'ACLSWKR', 'ADTIND', 'ADTOCC', 'AHGA', 'AHRSPAY', 'AHSCOL', 'AMARITL', 'AMJIND', 'AMJOCC',
                'ARACE', 'AREORGN', 'ASEX', 'AUNMEM', 'AUNTYPE', 'AWKSTAT', 'CAPGAIN', 'CAPLOSS', 'DIVVAL', 
                'FILESTAT', 'GRINREG', 'GRINST', 'HHDFMX', 'HHDREL', 'MARSUPWT', 'MIGMTR1', 'MIGMTR3', 'MIGMTR4', 
                'MIGSAME', 'MIGSUN', 'NOEMP', 'PARENT', 'PEFNTVTY', 'PEMNTVTY', 'PENATVTY', 'PRCITSHP', 'SEOTR', 
                'VETQVA', 'VETYN', 'WKSWORK', 'YEAR', 'PTOTVALB']

# %%
# you can read from the compressed file
df = pd.read_csv('census-income.data.gz', compression='gzip', names=columns_abbr, sep=r',', skipinitialspace=True)
#df.head()

# you can also unzip census-income.zip and read using the following
# df = pd.read_csv('census-income.csv', names=columns_abbr, sep=r',', skipinitialspace=True)

# %%
# you can see the DataFrame's info panel here
#df.dtypes
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 199523 entries, 0 to 199522
# Data columns (total 42 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   AAGE      199523 non-null  int64
#  1   ACLSWKR   199523 non-null  object
#  2   ADTIND    199523 non-null  int64
#  3   ADTOCC    199523 non-null  int64
#  4   AHGA      199523 non-null  object
#  5   AHRSPAY   199523 non-null  int64
#  6   AHSCOL    199523 non-null  object
#  7   AMARITL   199523 non-null  object
#  8   AMJIND    199523 non-null  object
#  9   AMJOCC    199523 non-null  object
#  10  ARACE     199523 non-null  object
#  11  AREORGN   198649 non-null  object
#  12  ASEX      199523 non-null  object
#  13  AUNMEM    199523 non-null  object
#  14  AUNTYPE   199523 non-null  object
#  15  AWKSTAT   199523 non-null  object
#  16  CAPGAIN   199523 non-null  int64
#  17  CAPLOSS   199523 non-null  int64
#  18  DIVVAL    199523 non-null  int64
#  19  FILESTAT  199523 non-null  object
#  20  GRINREG   199523 non-null  object
#  21  GRINST    199523 non-null  object
#  22  HHDFMX    199523 non-null  object
#  23  HHDREL    199523 non-null  object
#  24  MARSUPWT  199523 non-null  float64
#  25  MIGMTR1   199523 non-null  object
#  26  MIGMTR3   199523 non-null  object
#  27  MIGMTR4   199523 non-null  object
#  28  MIGSAME   199523 non-null  object
#  29  MIGSUN    199523 non-null  object
#  30  NOEMP     199523 non-null  int64
#  31  PARENT    199523 non-null  object
#  32  PEFNTVTY  199523 non-null  object
#  33  PEMNTVTY  199523 non-null  object
#  34  PENATVTY  199523 non-null  object
#  35  PRCITSHP  199523 non-null  object
#  36  SEOTR     199523 non-null  int64
#  37  VETQVA    199523 non-null  object
#  38  VETYN     199523 non-null  int64
#  39  WKSWORK   199523 non-null  int64
#  40  YEAR      199523 non-null  int64
#  41  PTOTVALB  199523 non-null  object
# dtypes: float64(1), int64(12), object(29)
# memory usage: 63.9+ MB

# %% [markdown]
# ### Q1 - Basic Dataset Manipulation [15 pts]
#
# #### Q1.1 Sort the instances in the dataset based on their age in descending order (AAGE attribute in the Census dataset corresponds to the age) and display top-20 instances. (5 pts)

# %%
# your code goes here
s = df.sort_values(by='AAGE', ascending=False)
s.head(20)
# Out:
#         AAGE          ACLSWKR  ADTIND  ADTOCC                        AHGA  \
# 46356     90  Not in universe       0       0    1st 2nd 3rd or 4th grade
# 96646     90  Not in universe       0       0        High school graduate
# 80878     90  Not in universe       0       0           7th and 8th grade
# 126478    90  Not in universe       0       0                  10th grade
# 149712    90  Not in universe       0       0  Bachelors degree(BA AB BS)
# 75243     90  Not in universe       0       0           7th and 8th grade
# 124107    90  Not in universe       0       0  Some college but no degree
# 143932    90  Not in universe       0       0    1st 2nd 3rd or 4th grade
# 3360      90  Not in universe       0       0    1st 2nd 3rd or 4th grade
# 34993     90  Not in universe       0       0        High school graduate
# 34995     90          Private      34      26  Some college but no degree
# 197183    90  Not in universe       0       0         Less than 1st grade
# 118999    90  Not in universe       0       0           7th and 8th grade
# 118997    90  Not in universe       0       0  Some college but no degree
# 185692    90  Not in universe       0       0    1st 2nd 3rd or 4th grade
# 67722     90  Not in universe       0       0           7th and 8th grade
# 72104     90  Not in universe       0       0           7th and 8th grade
# 132334    90          Private      33      30  Some college but no degree
# 173537    90  Not in universe       0       0            5th or 6th grade
# 5201      90  Not in universe       0       0    1st 2nd 3rd or 4th grade
#
#         AHRSPAY           AHSCOL                          AMARITL  \
# 46356         0  Not in universe                          Widowed
# 96646         0  Not in universe  Married-civilian spouse present
# 80878         0  Not in universe                          Widowed
# 126478        0  Not in universe                          Widowed
# 149712        0  Not in universe                    Never married
# 75243         0  Not in universe                          Widowed
# 124107        0  Not in universe                    Never married
# 143932        0  Not in universe                          Widowed
# 3360          0  Not in universe                          Widowed
# 34993         0  Not in universe                          Widowed
# 34995         0  Not in universe                        Separated
# 197183        0  Not in universe                          Widowed
# 118999        0  Not in universe                          Widowed
# 118997        0  Not in universe                    Never married
# 185692        0  Not in universe                          Widowed
# 67722         0  Not in universe                          Widowed
# 72104         0  Not in universe                          Widowed
# 132334        0  Not in universe                    Never married
# 173537        0  Not in universe                          Widowed
# 5201          0  Not in universe                          Widowed
#
#                                    AMJIND                          AMJOCC  \
# 46356         Not in universe or children                 Not in universe
# 96646         Not in universe or children                 Not in universe
# 80878         Not in universe or children                 Not in universe
# 126478        Not in universe or children                 Not in universe
# 149712        Not in universe or children                 Not in universe
# 75243         Not in universe or children                 Not in universe
# 124107        Not in universe or children                 Not in universe
# 143932        Not in universe or children                 Not in universe
# 3360          Not in universe or children                 Not in universe
# 34993         Not in universe or children                 Not in universe
# 34995   Finance insurance and real estate  Adm support including clerical
# 197183        Not in universe or children                 Not in universe
# 118999        Not in universe or children                 Not in universe
# 118997        Not in universe or children                 Not in universe
# 185692        Not in universe or children                 Not in universe
# 67722         Not in universe or children                 Not in universe
# 72104         Not in universe or children                 Not in universe
# 132334                       Retail trade                   Other service
# 173537        Not in universe or children                 Not in universe
# 5201          Not in universe or children                 Not in universe
#
#         ...       PEFNTVTY       PEMNTVTY       PENATVTY  \
# 46356   ...          Italy          Italy  United-States
# 96646   ...        Ecuador        Ecuador        Ecuador
# 80878   ...          Italy          Italy          Italy
# 126478  ...  United-States  United-States  United-States
# 149712  ...  United-States  United-States  United-States
# 75243   ...          Italy          Italy          Italy
# 124107  ...  United-States  United-States  United-States
# 143932  ...  United-States  United-States  United-States
# 3360    ...  United-States  United-States  United-States
# 34993   ...  United-States  United-States  United-States
# 34995   ...    Puerto-Rico    Puerto-Rico    Puerto-Rico
# 197183  ...  United-States  United-States  United-States
# 118999  ...  United-States  United-States  United-States
# 118997  ...    South Korea    South Korea    South Korea
# 185692  ...  United-States  United-States  United-States
# 67722   ...         Canada        Ireland  United-States
# 72104   ...  United-States  United-States  United-States
# 132334  ...  United-States  United-States  United-States
# 173537  ...          China          China          China
# 5201    ...  United-States  United-States  United-States
#
#                                            PRCITSHP SEOTR           VETQVA  \
# 46356             Native- Born in the United States     0               No
# 96646           Foreign born- Not a citizen of U S      0  Not in universe
# 80878   Foreign born- U S citizen by naturalization     0  Not in universe
# 126478            Native- Born in the United States     0  Not in universe
# 149712            Native- Born in the United States     0  Not in universe
# 75243   Foreign born- U S citizen by naturalization     0  Not in universe
# 124107            Native- Born in the United States     0  Not in universe
# 143932            Native- Born in the United States     0  Not in universe
# 3360              Native- Born in the United States     0  Not in universe
# 34993             Native- Born in the United States     0  Not in universe
# 34995   Native- Born in Puerto Rico or U S Outlying     0  Not in universe
# 197183            Native- Born in the United States     0  Not in universe
# 118999            Native- Born in the United States     0  Not in universe
# 118997  Foreign born- U S citizen by naturalization     0  Not in universe
# 185692            Native- Born in the United States     0  Not in universe
# 67722             Native- Born in the United States     0  Not in universe
# 72104             Native- Born in the United States     0  Not in universe
# 132334            Native- Born in the United States     0  Not in universe
# 173537          Foreign born- Not a citizen of U S      0  Not in universe
# 5201              Native- Born in the United States     0  Not in universe
#
#         VETYN  WKSWORK  YEAR  PTOTVALB
# 46356       1        0    95  - 50000.
# 96646       2        0    95  - 50000.
# 80878       2        0    94  - 50000.
# 126478      2        0    95  - 50000.
# 149712      2        0    94  - 50000.
# 75243       2        0    94  - 50000.
# 124107      2        0    95  - 50000.
# 143932      2        0    94  - 50000.
# 3360        2        0    95  - 50000.
# 34993       2        0    95  - 50000.
# 34995       2       40    94  - 50000.
# 197183      2        0    94  - 50000.
# 118999      2        0    95  - 50000.
# 118997      2        8    94  - 50000.
# 185692      2        0    95  - 50000.
# 67722       2        0    94  - 50000.
# 72104       2        0    94  - 50000.
# 132334      2       52    94  - 50000.
# 173537      2        0    95  - 50000.
# 5201        2        0    95  - 50000.
#
# [20 rows x 42 columns]

# %% [markdown]
# #### Q1.2 Discover the average age for top 7% oldest instances? Display two decimal places for the average age. (5 pts)

# %%
# your code goes here
s = df.sort_values(by='AAGE', ascending=False)

topSeven=s.head(int(len(s)*(7/100)))

avg=topSeven["AAGE"].mean()

result = round(avg, 2)

print(result)
# Out:
# 78.7

# %% [markdown]
# #### Q1.3 Find and display the median age of instances for each reported race (available in ARACE feature). [Hint: You can use groupby() function.] (5 pts)

# %%
# your code goes here

v = df.groupby(['ARACE'])['AAGE'].median()
print(v)
# Out:
# ARACE
# Amer Indian Aleut or Eskimo    25.0
# Asian or Pacific Islander      30.0
# Black                          28.0
# Other                          23.0
# White                          34.0
# Name: AAGE, dtype: float64

# %% [markdown]
# # Q2 - Identify the data scales and data types for each variable in census data. Identify the domain for each variable by checking the attributes' values. Then, create a data quality report for both categorical (nominal, ordinal) and continuous (interval, ratio) variables. [60 pts]
#
#
# #### Q2.1 Identifying the characteristics (20 pts)
# For data scales, identify whether an attribute is nominal, ordinal, interval, or ratio scale.
# For data types, identify the domain and provide an appropriate data type (integer, float, String, date, Boolean). See if that data type is correct in your dataframe.
# For domain, inspect each distinct value for each attribute. Identify missing values. use np.unique().
#
# You can create an external csv file consisting five [or more] columns (including feature name, description, scale, data type, and domain) and display it. A template is provided (See ___features.csv___). To understand what these features represent, please check the original documentation.
#
# Please include this file in your submission to get points.

# %%
# your code goes here
#information to help me organize the data
#Analyze every column 

for (names, series) in df.iteritems():
  print('ANALYZING THE COLUMN:', names)
  print('\tTotal number of records', series.size)
  print('\tNumber of missing values', series.isnull().sum())
  print('\tPercentage of missing values {0}%'.format(((series.isnull().sum()/series.size)*100)) )
  print('\tNumber of unique values', series.unique().size)
# Out:
# ANALYZING THE COLUMN: AAGE
# 	Total number of records 199523
# 	Number of missing values 0
# 	Percentage of missing values 0.0%
# 	Number of unique values 91
# ANALYZING THE COLUMN: ACLSWKR
# 	Total number of records 199523
# 	Number of missing values 0
# 	Percentage of missing values 0.0%
# 	Number of unique values 9
# ANALYZING THE COLUMN: ADTIND
# 	Total number of records 199523
# 	Number of missing values 0
# 	Percentage of missing values 0.0%
# 	Number of unique values 52
# ANALYZING THE COLUMN: ADTOCC
# 	Total number of records 199523
# 	Number of missing values 0
# 	Percentage of missing values 0.0%
# 	Number of unique values 47
# ANALYZING THE COLUMN: AHGA
# 	Total number of records 199523
# 	Number of missing values 0
# 	Percentage of missing values 0.0%
# 	Number of unique values 17
# ANALYZING THE COLUMN: AHRSPAY
# 	Total number of records 199523
# 	Number of missing values 0
# 	Percentage of missing values 0.0%
# 	Number of unique values 1240
# ANALYZING THE COLUMN: AHSCOL
# 	Total number of records 199523
# 	Number of missing values 0
# 	Percentage of missing values 0.0%
# 	Number of unique values 3
# ANALYZING THE COLUMN: AMARITL
# 	Total number of records 199523
# 	Number of missing values 0
# 	Percentage of missing values 0.0%
# 	Number of unique values 7
# ANALYZING THE COLUMN: AMJIND
# 	Total number of records 199523
# 	Number of missing values 0
# 	Percentage of missing values 0.0%
# 	Number of unique values 24
# ANALYZING THE COLUMN: AMJOCC
# 	Total number of records 199523
# 	Number of missing values 0
# 	Percentage of missing values 0.0%
# 	Number of unique values 15
# ANALYZING THE COLUMN: ARACE
# 	Total number of records 199523
# 	Number of missing values 0
# 	Percentage of missing values 0.0%
# 	Number of unique values 5
# ANALYZING THE COLUMN: AREORGN
# 	Total number of records 199523
# 	Number of missing values 874
# 	Percentage of missing values 0.43804473669702243%
# 	Number of unique values 10
# ANALYZING THE COLUMN: ASEX
# 	Total number of records 199523
# 	Number of missing values 0
# 	Percentage of missing values 0.0%
# 	Number of unique values 2
# ANALYZING THE COLUMN: AUNMEM
# 	Total number of records 199523
# 	Number of missing values 0
# 	Percentage of missing values 0.0%
# 	Number of unique values 3
# ANALYZING THE COLUMN: AUNTYPE
# 	Total number of records 199523
# 	Number of missing values 0
# 	Percentage of missing values 0.0%
# 	Number of unique values 6
# ANALYZING THE COLUMN: AWKSTAT
# 	Total number of records 199523
# 	Number of missing values 0
# 	Percentage of missing values 0.0%
# 	Number of unique values 8
# ANALYZING THE COLUMN: CAPGAIN
# 	Total number of records 199523
# 	Number of missing values 0
# 	Percentage of missing values 0.0%
# 	Number of unique values 132
# ANALYZING THE COLUMN: CAPLOSS
# 	Total number of records 199523
# 	Number of missing values 0
# 	Percentage of missing values 0.0%
# 	Number of unique values 113
# ANALYZING THE COLUMN: DIVVAL
# 	Total number of records 199523
# 	Number of missing values 0
# 	Percentage of missing values 0.0%
# 	Number of unique values 1478
# ANALYZING THE COLUMN: FILESTAT
# 	Total number of records 199523
# 	Number of missing values 0
# 	Percentage of missing values 0.0%
# 	Number of unique values 6
# ANALYZING THE COLUMN: GRINREG
# 	Total number of records 199523
# 	Number of missing values 0
# 	Percentage of missing values 0.0%
# 	Number of unique values 6
# ANALYZING THE COLUMN: GRINST
# 	Total number of records 199523
# 	Number of missing values 0
# 	Percentage of missing values 0.0%
# 	Number of unique values 51
# ANALYZING THE COLUMN: HHDFMX
# 	Total number of records 199523
# 	Number of missing values 0
# 	Percentage of missing values 0.0%
# 	Number of unique values 38
# ANALYZING THE COLUMN: HHDREL
# 	Total number of records 199523
# 	Number of missing values 0
# 	Percentage of missing values 0.0%
# 	Number of unique values 8
# ANALYZING THE COLUMN: MARSUPWT
# 	Total number of records 199523
# 	Number of missing values 0
# 	Percentage of missing values 0.0%
# 	Number of unique values 99800
# ANALYZING THE COLUMN: MIGMTR1
# 	Total number of records 199523
# 	Number of missing values 0
# 	Percentage of missing values 0.0%
# 	Number of unique values 10
# ANALYZING THE COLUMN: MIGMTR3
# 	Total number of records 199523
# 	Number of missing values 0
# 	Percentage of missing values 0.0%
# 	Number of unique values 9
# ANALYZING THE COLUMN: MIGMTR4
# 	Total number of records 199523
# 	Number of missing values 0
# 	Percentage of missing values 0.0%
# 	Number of unique values 10
# ANALYZING THE COLUMN: MIGSAME
# 	Total number of records 199523
# 	Number of missing values 0
# 	Percentage of missing values 0.0%
# 	Number of unique values 3
# ANALYZING THE COLUMN: MIGSUN
# 	Total number of records 199523
# 	Number of missing values 0
# 	Percentage of missing values 0.0%
# 	Number of unique values 4
# ANALYZING THE COLUMN: NOEMP
# 	Total number of records 199523
# 	Number of missing values 0
# 	Percentage of missing values 0.0%
# 	Number of unique values 7
# ANALYZING THE COLUMN: PARENT
# 	Total number of records 199523
# 	Number of missing values 0
# 	Percentage of missing values 0.0%
# 	Number of unique values 5
# ANALYZING THE COLUMN: PEFNTVTY
# 	Total number of records 199523
# 	Number of missing values 0
# 	Percentage of missing values 0.0%
# 	Number of unique values 43
# ANALYZING THE COLUMN: PEMNTVTY
# 	Total number of records 199523
# 	Number of missing values 0
# 	Percentage of missing values 0.0%
# 	Number of unique values 43
# ANALYZING THE COLUMN: PENATVTY
# 	Total number of records 199523
# 	Number of missing values 0
# 	Percentage of missing values 0.0%
# 	Number of unique values 43
# ANALYZING THE COLUMN: PRCITSHP
# 	Total number of records 199523
# 	Number of missing values 0
# 	Percentage of missing values 0.0%
# 	Number of unique values 5
# ANALYZING THE COLUMN: SEOTR
# 	Total number of records 199523
# 	Number of missing values 0
# 	Percentage of missing values 0.0%
# 	Number of unique values 3
# ANALYZING THE COLUMN: VETQVA
# 	Total number of records 199523
# 	Number of missing values 0
# 	Percentage of missing values 0.0%
# 	Number of unique values 3
# ANALYZING THE COLUMN: VETYN
# 	Total number of records 199523
# 	Number of missing values 0
# 	Percentage of missing values 0.0%
# 	Number of unique values 3
# ANALYZING THE COLUMN: WKSWORK
# 	Total number of records 199523
# 	Number of missing values 0
# 	Percentage of missing values 0.0%
# 	Number of unique values 53
# ANALYZING THE COLUMN: YEAR
# 	Total number of records 199523
# 	Number of missing values 0
# 	Percentage of missing values 0.0%
# 	Number of unique values 2
# ANALYZING THE COLUMN: PTOTVALB
# 	Total number of records 199523
# 	Number of missing values 0
# 	Percentage of missing values 0.0%
# 	Number of unique values 2

# %%
# please fill the information for the data characteristics in the given csv file. read it here and display.
import pandas as pd 


columns_names = ['Feature', 'Description', 'Data Type', 'Data Scale', 'Domain', 'Missing Values']

abt_path = '/Users/miskiabdirizak/jupyterNotebook/HW1/features.csv'
features_df = pd.read_csv(abt_path, names = columns_names, on_bad_lines='skip')

#index_col = 'col_name'
# N, O, I, R are Nominal, Ordinal, Interval, Ratio
features_df
# Out:
#      Feature                              Description Data Type Data Scale  \
# 0       AAGE                                      age     Int64          R
# 1    ACLSWKR                          class of worker    Object          N
# 2     ADTIND                            industry code     Int64          N
# 3     ADTOCC                          occupation code     Int64          N
# 4       AHGA                                education    Object          N
# 5    AHRSPAY                            wage per hour     Int64          R
# 6     AHSCOL             enrolled in edu inst last wk    Object          N
# 7    AMARITL                           marital status    Object          N
# 8     AMJIND                      major industry code    Object          N
# 9     AMJOCC                   major occurpation code    Object          N
# 10     ARACE                                     mace    Object          N
# 11   AREORGN                           hispanic orgin    Object          N
# 12      ASEX                                      sex    Object          N
# 13    AUNMEM                    member of labor union    Object          N
# 14   AUNTYPE                  reason for unemployment    Object          N
# 15   AWKSTAT        full or part time employment stat    Object          N
# 16   CAPGAIN                             capital gain     Int64          R
# 17   CAPLOSS                           capital losses     Int64          R
# 18    DIVVAL                    dividends from stocks     Int64        NaN
# 19  FILESTAT                         tax filer status    Object          N
# 20   GRINREG             region of previous residence    Object          N
# 21    GRINST              state of previous residence    Object          N
# 22    HHDFMX       detailed household and family stat    Object          N
# 23    HHDREL  detailed household summary in household    Object          N
# 24  MARSUPWT                          instance weight   Float64        NaN
# 25   MIGMTR1             migration code-change in msa    Object          N
# 26   MIGMTR3             migration code-change in reg    Object          N
# 27   MIGMTR4           migration code-move within reg    Object          N
# 28   MIGSAME            live in this house 1 year ago    Object          N
# 29    MIGSUN            migration prev res in sunbelt    Object          N
# 30     NOEMP          num persons worked for employer     Int64          R
# 31    PARENT                  family members under 18    Object          N
# 32  PEFNTVTY                  country of birth father    Object          N
# 33  PEMNTVTY                  country of birth mother    Object          N
# 34  PENATVTY                    country of birth self    Object          N
# 35  PRCITSHP                              citizenship    Object          N
# 36     SEOTR            own business or self employed     Int64          N
# 37   WKSWORK                     weeks worked in year     Int64          R
# 38      YEAR                                     year     Int64        NaN
# 39  PTOTVALB                                      NaN    Object          N
#
#                                                Domain Missing Values
# 0                                        {0, 1, 2, …}              0
# 1   {Not in universe, Federal government, Local go...
# 2                                        {0, 1, 2, …}              0
# 3                                        {0, 1, 2, …}              0
# 4   {Children, 7th and 8th grade, 9th grade, 10th ...              0
# 5                                        {0, 1, 2, …}              0
# 6   {Not in universe, High school, College or univ...              0
# 7   {Never married, Married-civilian spouse presen...              0
# 8   {Not in universe or children, Entertainment, S...              0
# 9   {Not in universe, Professional specialty, Othe...              0
# 10  {White, Black, Other, Amer Indian Aleut or Esk...              0
# 11  {Mexican (Mexicano), Mexican-American, Puerto ...            874
# 12                                    {Female, Male.}              0
# 13                        {Not in universe, No, Yes.}              0
# 14                                                 {}              0
# 15                                                 {}              0
# 16                                       {0, 1, 2, …}              0
# 17                                       {0, 1, 2, …}              0
# 18                                       {0, 1, 2, …}              0
# 19  {Nonfiler, Joint one under 65 & one 65+, Joint...              0
# 20  {Not in universe, South, Northeast, West, Midw...              0
# 21  {Not in universe, Utah, Michigan, North Caroli...              0
# 22  {Child <18 never marr not in subfamily, Other ...            NaN
# 23  {Child under 18 never married, Other relative ...              0
# 24                                       {0, 1, 2, …}              0
# 25  {Not in universe, Nonmover, MSA to MSA, NonMSA...              0
# 26  {Not in universe, Nonmover, Same county, Diffe...              0
# 27  {Not in universe, Nonmover, Same county, Diffe...              0
# 28       {Not in universe under 1 year old, Yes, No.}              0
# 29                        {Not in universe, Yes, No.}              0
# 30                                       {0, 1, 2, …}              0
# 31  {Both parents present, Neither parent present,...              0
# 32  {Mexico, United-States, Puerto-Rico, Dominican...              0
# 33  {India, Mexico, United-States, Puerto-Rico, Do...              0
# 34  {United-States, Mexico, Puerto-Rico, Peru, Can...              0
# 35  {Native- Born in the United States, Foreign bo...              0
# 36                                         {0, 2, 1.}              0
# 37                                       {0, 1, 2, …}              0
# 38                                        {1994,1995}              0
# 39                                                 {}              0

# %% [markdown]
# #### Q2.2 Create a Data Quality Report (40 pts)
#
# Include the bar plots and histograms for visualizing the distributions. You may get your descriptions from features.csv file.
#
# The examples for a continuous and a categorical feature can be seen below. You do not need to use jupyter formatting provided here. You can print a DataFrame or read a csv, and display it. If you will read from a csv, make sure you have that csv in your submission zip file.

# %%
# your code goes here

import pandas as pd
df = pd.read_csv('census-income.data.gz', compression='gzip', names=columns_abbr, sep=r',', skipinitialspace=True)
features_df = pd.read_csv(abt_path, names = columns_names, on_bad_lines='skip')


# Data Quality Report for Continous Features
continous_Headers = ['Count', 'Miss %', 'Card.', 'Min', '1st Qrt.', 'Mean', 'Median', '3rd Qrt', 'Max', 'Std. Dev.']

#Continous features
conFeat = ['AAGE', 'AHRSPAY', 'CAPGAIN', 'CAPLOSS', 'DIVVAL','NOEMP', 'WKSWORK']
#Categorical Fetures [
catFeat = ['ACLSWKR', 'ADTIND', 'ADTOCC', 'AHGA','AHSCOL', 'AMARITL', 'AMJIND', 'AMJOCC','ARACE', 'AREORGN', 'ASEX', 'AUNMEM', 'AUNTYPE', 'AWKSTAT','FILESTAT', 'GRINREG', 'GRINST', 'HHDFMX', 'HHDREL', 'MARSUPWT', 'MIGMTR1', 'MIGMTR3', 'MIGMTR4', 
           'MIGSAME', 'MIGSUN','PARENT', 'PEFNTVTY', 'PEMNTVTY', 'PENATVTY', 'PRCITSHP', 'SEOTR', 
           'VETQVA', 'VETYN', 'YEAR', 'PTOTVALB']

dqr_continous = pd.DataFrame(index = conFeat, columns = continous_Headers)

dqr_continous.index.name = 'FEATURE NAME'

columns = df[conFeat]

#Count C
count = columns.count()
dqr_continous[continous_Headers[0]] = count

#MISS %
percents = ['']*len(conFeat)
for col in columns:
    percents[conFeat.index(col)] = 0.00

dqr_continous[continous_Headers[1]] = percents

#CARDINALITY
dqr_continous[continous_Headers[2]] = columns.nunique()

#MINIMUM
dqr_continous[continous_Headers[3]] = columns.min()

#1ST QUARTILE
dqr_continous[continous_Headers[4]] = columns.quantile(0.25)

#MEAN
dqr_continous[continous_Headers[5]] = round(columns.mean(), 2)

#MEDIAN
dqr_continous[continous_Headers[6]] = columns.median()

#3rd QUARTILE
dqr_continous[continous_Headers[7]] = columns.quantile(0.75)

#MAX
dqr_continous[continous_Headers[8]] = columns.max()

#STANDARD DEVIATION
dqr_continous[continous_Headers[9]] = round(columns.std(),2)

print(dqr_continous)
# Out:
#                Count  Miss %  Card.  Min  1st Qrt.    Mean  Median  3rd Qrt  \
# FEATURE NAME
# AAGE          199523     0.0     91    0      15.0   34.49    33.0     50.0
# AHRSPAY       199523     0.0   1240    0       0.0   55.43     0.0      0.0
# CAPGAIN       199523     0.0    132    0       0.0  434.72     0.0      0.0
# CAPLOSS       199523     0.0    113    0       0.0   37.31     0.0      0.0
# DIVVAL        199523     0.0   1478    0       0.0  197.53     0.0      0.0
# NOEMP         199523     0.0      7    0       0.0    1.96     1.0      4.0
# WKSWORK       199523     0.0     53    0       0.0   23.17     8.0     52.0
#
#                 Max  Std. Dev.
# FEATURE NAME
# AAGE             90      22.31
# AHRSPAY        9999     274.90
# CAPGAIN       99999    4697.53
# CAPLOSS        4608     271.90
# DIVVAL        99999    1984.16
# NOEMP             6       2.37
# WKSWORK          52      24.41

# %%
import pandas as pd

ddf = pd.read_csv('census-income.data.gz', compression='gzip', names=columns_abbr, sep=r',', skipinitialspace=True)
features_df = pd.read_csv(abt_path, names = columns_names, on_bad_lines='skip')

# Data Quality Report for Categorical Features
categorical_Headers = ['Count', 'Miss %', 'Card.', 'Mode', 'Mode Freq', 'Mode %', '2nd Mode', '2nd Mode Freq', '2nd Mode %']

#Categorical Fetures 
catFeat = ['ACLSWKR', 'ADTIND', 'ADTOCC', 'AHGA','AHSCOL', 'AMARITL', 'AMJIND', 'AMJOCC','ARACE', 'AREORGN', 'ASEX', 'AUNMEM', 'AUNTYPE', 'AWKSTAT','FILESTAT', 'GRINREG', 'GRINST', 'HHDFMX', 'HHDREL', 'MARSUPWT', 'MIGMTR1', 'MIGMTR3', 'MIGMTR4', 
           'MIGSAME', 'MIGSUN','PARENT', 'PEFNTVTY', 'PEMNTVTY', 'PENATVTY', 'PRCITSHP', 'SEOTR', 
           'VETQVA', 'VETYN', 'YEAR', 'PTOTVALB']


dqr_categorical = pd.DataFrame(index=catFeat, columns=categorical_Headers)

dqr_categorical.index.name = 'FEATURE NAME'

columns = df[catFeat]

#COUNT
count = columns.count()
dqr_categorical[categorical_Headers[0]] = count


#CARDINALITY
dqr_categorical[categorical_Headers[2]] = columns.nunique()


#preparing arrays for storing data
amt = len(catFeat)
missPercents = ['']*amt
modeFreqs = ['']*amt
modes = ['']*amt
modes2 = ['']*amt
modePercents = ['']*amt
modeFreqs2 = ['']*amt
modePercents2 = ['']*amt

for col in columns:
    values = columns[col].value_counts()
    index = catFeat.index(col)

    #MISS %
    try:
        qMarksCount = values.loc[' ?']
        percent = (qMarksCount/count[index]) * 100
        missPercents[index] = round(percent, 2)

        dqr_categorical['Card.'][index] -= 1
    except Exception as e:
            missPercents[index] = 0.00

    #MODES
    mode = values.index[0]
    mode2 = values.index[1]
    modes[index] = mode
    modes2[index] = mode2
        
    #MODE FREQ
    modeCount = values.loc[mode]
    modeCount2 = values.loc[mode2]
    modeFreqs[index] = modeCount
    modeFreqs2[index] = modeCount2

    #MODE %
    miss = missPercents[index]
        
    modePer = (modeCount/(count[index]*((100-miss)/100)))*100
    modePercents[index] = round(modePer, 2)
        
    modePer2 = (modeCount2/(count[index]*((100-miss)/100)))*100
    modePercents2[index] = round(modePer2, 2)

dqr_categorical[categorical_Headers[1]] = missPercents
dqr_categorical[categorical_Headers[3]] = modes
dqr_categorical[categorical_Headers[4]] = modeFreqs
dqr_categorical[categorical_Headers[5]] = modePercents
dqr_categorical[categorical_Headers[6]] = modes2
dqr_categorical[categorical_Headers[7]] = modeFreqs2
dqr_categorical[categorical_Headers[8]] = modePercents2

print(dqr_categorical)

# %% [markdown]
#  ### Example Data Quality Report for Continuous Variables
# | Feature | Desc. | Count | % of Missing | Card. | Min. | Q1 | Median | Q3 | Max. | Mean | Std. Dev. | Notes |
# | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- |
# | AAGE | Age | 199,523 | 0 | 91 | 0 | 15 | 33 | 50 | 90 | 34.49 | 22.31 |  |
#
# ### Example Data Quality Report for Categorical Variables
# | Feature | Desc. | Count | % of Missing | Card. | Mode | Mode Freq. | Mode % | 2nd Mode | 2nd Mode Freq. | 2nd Mode Perc | Notes |
# | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- |
# | ACLSWKR | Class of worker | 199,523 | 0 | 9 | Not in Universe | 100,245 | 50.24 | Private | 72,028 |  36.10 |  |

# %%
# bar plots for categorical features 
from tkinter import Label
import matplotlib
import matplotlib.pyplot as plt
import pandas as pd
#bar ol
df = pd.read_csv('census-income.data.gz', compression='gzip', names=columns_abbr, sep=r',', skipinitialspace=True)
features_df = pd.read_csv(abt_path, names = columns_names, on_bad_lines='skip')

ffig,ax=plt.subplots(4,8,figsize=(20,20))

df.value_counts().plot(kind = 'bar', ax=ax[0,0],title=df)

plt.show()

# %%
# histograms for continuous features
from tkinter import Label
import matplotlib
import matplotlib.pyplot as plt
import pandas as pd
 
df = pd.read_csv('census-income.data.gz', compression='gzip', names=columns_abbr, sep=r',', skipinitialspace=True)
features_df = pd.read_csv('/Users/miskiabdirizak/jupyterNotebook/HW1/features.csv', names=columns_abbr, sep=r',', skipinitialspace=True)

df_for_hist = df._get_numeric_data()
print(df_for_hist)

col_list = []
for (name, series) in df.iteritems():
  if series.dtype != 'object':
    col_list.append(name)

fig, ax = plt.subplots(3,3,figsize=(20,20)) # get a bigger figure
df_for_hist = df[col_list]
df_for_hist.hist(bins=14, alpha=0.5, ax=ax[0][0])

# %% [markdown]
# ### Q3 Outlier Identification (25 pts)
#
# #### Q3.1 For each continuous feature, identify the outliers using the IQR method. (15 pts)
# For each feature, report the lower and upper bounds and number of instances that are identified as outliers.
# Then, display boxplots and discuss if your outliers analysis makes sense. Discuss why you would (or would not) use the IQR method.

# %%
# your code goes here
import numpy as np
import pandas as pd

ddf = pd.read_csv('census-income.data.gz', compression='gzip', names=columns_abbr, sep=r',', skipinitialspace=True)
features_df = pd.read_csv(abt_path, names = columns_names, on_bad_lines='skip')

ffig, axes = plt.subplots(nrows=4, ncols=3, figsize=(40, 20))

x = 0
y = 0
x_Max = 2

#IQR Column Names
iqr_cols = ['Feature', 'IQR', 'Lower Bound', 'Upper Bound']
#Build Data Frame
iqr_df = pd.DataFrame(columns=iqr_cols)
for col in df.columns: #iterate through col and check for continous features
    if(features_df.loc[col]['scale (N, O, I, R)'] == 'R' or features_df.loc[col]['scale (N, O, I, R)'] == 'I'):
        Q3 = dqr_continous.loc[col]['Q3'] #get q1 anf q3 from continous data quality report
        Q1 = dqr_continous.loc[col]['Q1']
        iqr = Q3-Q1 #solve for iqr
        entry = {'Feature':col, 'IQR':iqr, 'Lower Bound':Q1-(1.5*iqr), 'Upper Bound':Q3+(1.5*iqr)} #solve for bounds
        iqr_df.loc[len(iqr_df)] = entry
        a = df.boxplot(column=col, ax=axes[y,x], grid=False, vert=False, ) #Build boxplot
        a.set_title(col)
        if(x == x_max): #checking for outliers
            x = 0
            y += 1
        else:
            x += 1
iqr_df.set_index('Feature', inplace=True)
print(iqr_df)

#No, the outliers do not make sense b/c some outliers report back negative which is impossible. 
#IQR is not suitable because some of the values are in the extreme. Some are either too large or too small.

# %% [markdown]
# #### Q3.2. Replace the outlying values in WKSWORK, MARSUPWT and AAGE features. (10 pts)
# Use clamping with upper and lower bounds you found in the previous step. Report how many individual cells are being updated for each feature.

# %%
# your code goes
import numpy as np
df = pd.read_csv('census-income.data.gz', compression='gzip', names=columns_abbr, sep=r',', skipinitialspace=True)
features_df = pd.read_csv(abt_path, names = columns_names, on_bad_lines='skip')

Q3 = dqr_continous.loc[c]['Q3'] #get q1 anf q3 from continous data quality report
Q1 = dqr_continous.loc[c]['Q1']

iqr = Q3-Q1 #solve for iqr
lowerBound = q1-(1.5*iqr)
upperBound = q3+(1.5*iqr)
np.clip(iqr_df, lowerBound,upperBound, out = iqr_df)
print(iqr_df)

# %% [markdown]
# ### Q4 Normalization (10 pts)
#
# Normalize the MARSUPWT, AAGE, NOEMP, CAPGAIN, and CAPLOSS features
# * Use range normalization for MARSUPWT feature
# * Use robust scaling for NOEMP feature
# * Use Z-score normalization for AAGE feature
# * Use log scaling for CAPGAIN and CAPLOSS features (impute your zero values with 10 before transformation to avoid undefined  $log_{b}0$)

# %%
# your code goes here
from sklearn import preprocessing

df = pd.read_csv('census-income.data.gz', compression='gzip', names=columns_abbr, sep=r',', skipinitialspace=True)
features_df = pd.read_csv(abt_path, names = columns_names, on_bad_lines='skip')

#Range Normalization
print("Range Normalization")
range_normalization = (df["MARSUPWT"]-df["MARSUPWT"].min()) / (df["MARSUPWT"].max()-df["MARSUPWT"].min())
print(range_normalization)

#Robust Scaling
print("Robust Scaling")
robust_scaling = (df["NOEMP"] - df["NOEMP"].median()) / (df["NOEMP"].quantile(0.75) - df["NOEMP"].quantile(0.25))
print(robust_scaling)

#Z-Score Normalization
df['AAGE'] = (df['AAGE'] - df['AAGE'].mean())/df['AAGE'].std(ddof=0)
print(df['AAGE'])

# Log Scaling
print("Log Scaling")
df = pd.DataFrame(np.random.uniform(-1,1,(199524,1)))
df['CAPGAIN'] = (1+df[0])/2 # (-1,1] -> (0,1]
df['CAPGAIN'] = np.log(df['CAPGAIN'])
print(df)

df = pd.DataFrame(np.random.uniform(-1,1,(199524,1)))
df['CAPLOSS'] = (1+df[0])/2 # (-1,1] -> (0,1]
df['CAPLOSS'] = np.log(df['CAPLOSS'])
print(df)
# Out:
# Range Normalization
# 0         0.089278
# 1         0.054552
# 2         0.051244
# 3         0.092396
# 4         0.055391
#             ...
# 199518    0.049274
# 199519    0.034875
# 199520    0.101252
# 199521    0.248517
# 199522    0.096262
# Name: MARSUPWT, Length: 199523, dtype: float64
# Robust Scaling
# 0        -0.25
# 1         0.00
# 2        -0.25
# 3        -0.25
# 4        -0.25
#           ...
# 199518   -0.25
# 199519    0.00
# 199520    1.25
# 199521   -0.25
# 199522    1.25
# Name: NOEMP, Length: 199523, dtype: float64
# 0         1.725879
# 1         1.053560
# 2        -0.739291
# 3        -1.142682
# 4        -1.097861
#             ...
# 199518    2.353376
# 199519    1.367309
# 199520    0.560526
# 199521   -0.828933
# 199522   -0.111793
# Name: AAGE, Length: 199523, dtype: float64
# Log Scaling
#                0   CAPGAIN
# 0      -0.626780 -1.678734
# 1      -0.018161 -0.711475
# 2       0.591698 -0.228346
# 3      -0.565559 -1.526843
# 4      -0.564572 -1.524574
# ...          ...       ...
# 199519 -0.810863 -2.358433
# 199520 -0.599413 -1.607972
# 199521  0.398167 -0.357985
# 199522  0.003659 -0.689494
# 199523 -0.361503 -1.141786
#
# [199524 rows x 2 columns]
#                0   CAPLOSS
# 0       0.534331 -0.265053
# 1       0.778432 -0.117415
# 2      -0.493524 -1.373425
# 3       0.673430 -0.178272
# 4       0.880221 -0.061758
# ...          ...       ...
# 199519 -0.195758 -0.911002
# 199520 -0.903656 -3.032973
# 199521  0.695918 -0.164923
# 199522  0.405618 -0.352670
# 199523  0.331957 -0.406498
#
# [199524 rows x 2 columns]
